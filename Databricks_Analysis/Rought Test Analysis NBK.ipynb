# %%
from pyspark.sql.functions import *

# %%
df = (spark.read
      .option("header", True)
      .option("inferSchema", False)
      .csv("abfss://basecontainer@spotifydeprojectadls.dfs.core.windows.net/staging/tracks_features"))

print(df.count())
df.display()

# %%
df = spark.table('spotifyproject.bronze.tracks_features')

df.summary().show()

# %%
# %sql
select * from spotifyproject.bronze.tracks_features
where year < 1900;

# %%
# %sql
select * from spotifyproject.silver.tracks_features
where year < 1900;
