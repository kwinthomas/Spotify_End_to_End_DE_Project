# %%
# %sql
CREATE CATALOG IF NOT EXISTS spotifyproject
MANAGED LOCATION 'abfss://basecontainer@spotifydeprojectadls.dfs.core.windows.net/';

CREATE SCHEMA IF NOT EXISTS spotifyproject.bronze;

CREATE SCHEMA IF NOT EXISTS spotifyproject.silver;

CREATE SCHEMA IF NOT EXISTS spotifyproject.gold;
